# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("D:\Semester 4\Data Analysis\Research Dataset\GapMinder Codebook.csv", low_memory=False)

# %%
print("The no. of rows in the whole dataset is : ", len(df))            #Number of observations (Rows)
print("The no. of columns in the whole dataset is : ",len(df.columns))  #Number of Variables (Columns)
# Out:
# The no. of rows in the whole dataset is :  213
# The no. of columns in the whole dataset is :  16

# %%
df.describe()
# Out:
#             country incomeperperson alcconsumption armedforcesrate  \
# count           213             213            213             213
# unique          213             191            181             165
# top     Afghanistan
# freq              1              23             26              49
#
#        breastcancerper100th co2emissions femaleemployrate hivrate  \
# count                   213          213              213     213
# unique                  137          201              154      47
# top
# freq                     40           13               35      66
#
#        internetuserate lifeexpectancy oilperperson polityscore  \
# count              213            213          213         213
# unique             193            190           64          22
# top
# freq                21             22          150          52
#
#        relectricperperson suicideper100th employrate urbanrate
# count                 213             213        213       213
# ...

# %%
df.head(15)
# Out:
#                 country incomeperperson alcconsumption armedforcesrate  \
# 0           Afghanistan                           0.03       0.5696534
# 1               Albania     1914.996551           7.29       1.0247361
# 2               Algeria     2231.993335           0.69        2.306817
# 3               Andorra      21943.3399          10.17
# 4                Angola     1381.004268           5.57       1.4613288
# 5   Antigua and Barbuda     11894.46407           8.17
# 6             Argentina     10749.41924           9.35        0.560987
# 7               Armenia     1326.741757          13.66       2.6184384
# 8                 Aruba
# 9             Australia     25249.98606          10.21       0.4862799
# 10              Austria     26692.98411           12.4       0.8155798
# 11           Azerbaijan     2344.896916          13.34       1.9767462
# 12              Bahamas     19630.54055           8.65       0.5452863
# ...

# %%
df = df._convert(numeric=True)

# %%
df.dtypes
# Out:
# country                  object
# incomeperperson         float64
# alcconsumption          float64
# armedforcesrate         float64
# breastcancerper100th    float64
# co2emissions            float64
# femaleemployrate        float64
# hivrate                 float64
# internetuserate         float64
# lifeexpectancy          float64
# oilperperson            float64
# polityscore             float64
# relectricperperson      float64
# suicideper100th         float64
# employrate              float64
# urbanrate               float64
# dtype: object

# %%
df.describe()
# Out:
#        incomeperperson  alcconsumption  armedforcesrate  breastcancerper100th  \
# count       190.000000      187.000000       164.000000            173.000000
# mean       8740.966076        6.689412         1.444016             37.402890
# std       14262.809083        4.899617         1.709008             22.697901
# min         103.775857        0.030000         0.000000              3.900000
# 25%         748.245151        2.625000         0.480907             20.600000
# 50%        2553.496056        5.920000         0.930638             30.000000
# 75%        9379.891166        9.925000         1.611383             50.300000
# max      105147.437700       23.010000        10.638521            101.100000
#
#        co2emissions  femaleemployrate     hivrate  internetuserate  \
# count  2.000000e+02        178.000000  147.000000       192.000000
# mean   5.030226e+09         47.549438    1.935442        35.632716
# ...

# %%
df.head(15)
# Out:
#                 country  incomeperperson  alcconsumption  armedforcesrate  \
# 0           Afghanistan              NaN            0.03         0.569653
# 1               Albania      1914.996551            7.29         1.024736
# 2               Algeria      2231.993335            0.69         2.306817
# 3               Andorra     21943.339900           10.17              NaN
# 4                Angola      1381.004268            5.57         1.461329
# 5   Antigua and Barbuda     11894.464070            8.17              NaN
# 6             Argentina     10749.419240            9.35         0.560987
# 7               Armenia      1326.741757           13.66         2.618438
# 8                 Aruba              NaN             NaN              NaN
# 9             Australia     25249.986060           10.21         0.486280
# 10              Austria     26692.984110           12.40         0.815580
# 11           Azerbaijan      2344.896916           13.34         1.976746
# ...

# %%
df.corr(method='pearson')
# Out:
#                       incomeperperson  alcconsumption  armedforcesrate  \
# incomeperperson              1.000000        0.295392         0.015255
# alcconsumption               0.295392        1.000000        -0.196560
# armedforcesrate              0.015255       -0.196560         1.000000
# breastcancerper100th         0.731399        0.493298        -0.042610
# co2emissions                 0.270705        0.113518        -0.057967
# femaleemployrate             0.028358        0.169747        -0.332640
# hivrate                     -0.198452       -0.062414        -0.168651
# internetuserate              0.750939        0.534477         0.037762
# lifeexpectancy               0.601516        0.312994         0.186818
# oilperperson                 0.541893       -0.245880         0.521558
# polityscore                  0.281223        0.430950        -0.341664
# relectricperperson           0.651637        0.035334         0.034922
# ...

# %%
#sns.heatmap(df.corr(method='pearson'), annot=True)
sns.heatmap(df.corr(method='pearson'))
# Out:
# <AxesSubplot:>

# %%
df.corr(method='spearman')
# Out:
#                       incomeperperson  alcconsumption  armedforcesrate  \
# incomeperperson              1.000000        0.443534         0.273869
# alcconsumption               0.443534        1.000000        -0.072933
# armedforcesrate              0.273869       -0.072933         1.000000
# breastcancerper100th         0.699058        0.537508         0.113682
# co2emissions                 0.455318        0.248985         0.210724
# femaleemployrate            -0.197307        0.175305        -0.373663
# hivrate                     -0.431338       -0.082364        -0.387290
# internetuserate              0.862242        0.551285         0.242957
# lifeexpectancy               0.854227        0.383942         0.269332
# oilperperson                 0.843416        0.108990         0.055315
# polityscore                  0.466409        0.514855        -0.195276
# relectricperperson           0.887543        0.369193         0.152304
# ...

# %%
sns.heatmap(df.corr(method='spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# just to let you know Aniruddha !!!
#
# that you can use pearson and spearman coeffecient correlations, through scipy as :
# from scipy.stats import pearsonr, spearmanr
# pearsonr(df['A'], df['B'])
# spearmanr(df['A'], df['B'])
#
# CAUTION : Aniruddha !!!! you can only use this, when dataset has no NAN values. Got it!!

# %% [markdown]
# # Research Question 1 : How Armed-Force-Rate is affecting life expectancy and suicide/person rate?

# %% [markdown]
# ## Part-1 : Armed-Force-Rate v/s life expectancy

# %%
'''print("count of similar suiciderate distributed over countries, plus percentage of that value")
suicideRate = df["suicideper100th"].value_counts(sort=False, dropna = False)
print (suicideRate)

suicideRatepercentage = df["suicideper100th"].value_counts(sort=False, normalize=True)
print (suicideRatepercentage)'''
# Out:
# 'print("count of similar suiciderate distributed over countries, plus percentage of that value")\nsuicideRate = df["suicideper100th"].value_counts(sort=False, dropna = False)\nprint (suicideRate)\n\nsuicideRatepercentage = df["suicideper100th"].value_counts(sort=False, normalize=True)\nprint (suicideRatepercentage)'

# %%
'''print("count of similar employment rate distributed over countries, plus percentage of that value")
Employee = df["employrate"].value_counts(sort=False, dropna = False)
print (Employee)

EmployeeRate = df["employrate"].value_counts(sort=False, normalize=True)
print (EmployeeRate)'''
# Out:
# 'print("count of similar employment rate distributed over countries, plus percentage of that value")\nEmployee = df["employrate"].value_counts(sort=False, dropna = False)\nprint (Employee)\n\nEmployeeRate = df["employrate"].value_counts(sort=False, normalize=True)\nprint (EmployeeRate)'

# %%
'''print("count of similar armedforce rate distributed over countries, plus percentage of that value")
ArmedForceRate = df["armedforcesrate"].value_counts(sort=False, dropna = False)
print (ArmedForceRate)

ArmedForceRatePercent = df["armedforcesrate"].value_counts(sort=False, normalize=True)
print (ArmedForceRatePercent)'''
# Out:
# 'print("count of similar armedforce rate distributed over countries, plus percentage of that value")\nArmedForceRate = df["armedforcesrate"].value_counts(sort=False, dropna = False)\nprint (ArmedForceRate)\n\nArmedForceRatePercent = df["armedforcesrate"].value_counts(sort=False, normalize=True)\nprint (ArmedForceRatePercent)'

# %% [markdown]
# pandas.DataFrame.corr
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html
#
# Aniruddha, Man !!! Please do remember that corr(), should be used after df[].corr()
# if not then the
#
# "ValueError: zero-size array to reduction operation fmin which has no identity"
# which you can't Understand, right now !!!

# %%
df[["armedforcesrate", "lifeexpectancy"]].corr()
# Out:
#                  armedforcesrate  lifeexpectancy
# armedforcesrate         1.000000        0.186818
# lifeexpectancy          0.186818        1.000000

# %%
sns.heatmap(df[["armedforcesrate", "lifeexpectancy"]].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df['armedforcesrate'].corr(df['lifeexpectancy'])
# Out:
# 0.18681827883086638

# %% [markdown]
# Conclusion : ArmedforceRate has Positive correaltion with lifeexpectancy.
#
# which means when ArmedforceRate increases then lifeexpectancy will increase and the value of that direct coeffecient is 0.18681827883086638

# %% [markdown]
# ## Part-2 : Armed-Force-Rate v/s suicide/person rate

# %%
sns.heatmap(df[["armedforcesrate", "suicideper100th"]].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df[["armedforcesrate", "suicideper100th"]].corr()
# Out:
#                  armedforcesrate  suicideper100th
# armedforcesrate         1.000000        -0.113688
# suicideper100th        -0.113688         1.000000

# %%
df['armedforcesrate'].corr(df['suicideper100th'])
# Out:
# -0.11368787076445443

# %% [markdown]
# Conclusion : ArmedforceRate has Negative correaltion with suicideper100th.
#
# which means when ArmedforceRate increases then suicideper100th will decrease and the value of that inverse coeffecient is -0.11368787076445443

# %% [markdown]
# ### Extra Question : Does High Income Affects Suiciderate ?

# %%
df[["incomeperperson", "suicideper100th"]].corr()
# Out:
#                  incomeperperson  suicideper100th
# incomeperperson         1.000000         0.006555
# suicideper100th         0.006555         1.000000

# %%
subset1 = df.loc[(df["incomeperperson"]>=2000) & (df["suicideper100th"]>8),["country", "incomeperperson", "suicideper100th"]]
subset1
# Out:
#                               country  incomeperperson  suicideper100th
# 9                           Australia     25249.986060         8.470030
# 10                            Austria     26692.984110        13.094370
# 16                            Belarus      2737.670379        26.874690
# 17                            Belgium     24496.048260        15.953850
# 18                             Belize      3545.652174         9.388796
# 23             Bosnia and Herzegovina      2183.344867        11.836716
# 24                           Botswana      4189.436587        11.213970
# 27                           Bulgaria      2549.558474         9.216544
# 32                             Canada     25575.352620        10.100990
# 37                              Chile      6334.105194        10.171870
# 38                              China      2425.471293        16.913248
# 46                            Croatia      6338.494668        14.776250
# ...

# %%
print("No. of Countries that have Income-per-person >= $2000 & suicideper100th > 8000 :\n")
print("Only",len(subset1), "such countries are there. ")
# Out:
# No. of Countries that have Income-per-person >= $2000 & suicideper100th > 8000 :
#
# Only 56 such countries are there.

# %%
subset1.plot(x='incomeperperson', y='suicideper100th', kind='scatter')
plt.show()

# %%
correlation1 = subset1['incomeperperson'].corr(subset1['suicideper100th'], method= 'pearson')
print(correlation1)
# Out:
# -0.20406045523782845

# %% [markdown]
#  This correlation represents that as income of a person increases, suciderate / 100 thousands decreases, whereas even in the graph you can observe that as income is increasing, sucide rate is decreasing.

# %% [markdown]
# # Research Question 2 : Is Alcohol-Consumption increasing with Income-Per-Person ?

# %%
df[["incomeperperson", "alcconsumption"]].corr()
# Out:
#                  incomeperperson  alcconsumption
# incomeperperson         1.000000        0.295392
# alcconsumption          0.295392        1.000000

# %%
#subset2 = df.loc[(df["alcconsumption"])  (df["incomeperperson"]),["country", "incomeperperson", "alcconsumption"]]
subset2 = df.loc[: , ["incomeperperson", "alcconsumption"]]
subset2
# Out:
#      incomeperperson  alcconsumption
# 0                NaN            0.03
# 1        1914.996551            7.29
# 2        2231.993335            0.69
# 3       21943.339900           10.17
# 4        1381.004268            5.57
# ..               ...             ...
# 208       722.807559            3.91
# 209              NaN             NaN
# 210       610.357367            0.20
# 211       432.226337            3.56
# 212       320.771890            4.96
#
# [213 rows x 2 columns]

# %%
subset2.plot(x="incomeperperson", y="alcconsumption", kind="scatter")
plt.show()

# %%
correlation2 = subset2['incomeperperson'].corr(subset2['alcconsumption'], method= 'pearson')
print(correlation2)
# Out:
# 0.2953924872842334

# %% [markdown]
#  This correlation represents that as income of a person increases, Alcohol Consumption increases, but this is increase is very low and that is why high easrning country is not consuming Alcohol compared to low-earning Countries.

# %% [markdown]
# ### Extra Question : What is level of alcohol consumption in small earning countries ?

# %%
subset3 = df.loc[(df["incomeperperson"]>=2000) & (df["incomeperperson"]<=20000) & (df["alcconsumption"]>8),["country", "incomeperperson", "alcconsumption"]]
subset3
# Out:
#                     country  incomeperperson  alcconsumption
# 5       Antigua and Barbuda     11894.464070            8.17
# 6                 Argentina     10749.419240            9.35
# 11               Azerbaijan      2344.896916           13.34
# 12                  Bahamas     19630.540550            8.65
# 16                  Belarus      2737.670379           18.85
# 23   Bosnia and Herzegovina      2183.344867            9.60
# 25                   Brazil      4699.411262           10.08
# 27                 Bulgaria      2549.558474           11.40
# 37                    Chile      6334.105194            8.81
# 46                  Croatia      6338.494668           15.00
# 48                   Cyprus     15313.859350            8.84
# 49               Czech Rep.      7381.312751           16.47
# 52                 Dominica      6147.779610            8.68
# 59                  Estonia      6238.537506           17.24
# ...

# %%
print("The Countries whose per-capita income is around $2000 to $20,000 and have alcohol consumption more than 8 litres/person are :\n")
print(len(subset3))
# Out:
# The Countries whose per-capita income is around $2000 to $20,000 and have alcohol consumption more than 8 litres/person are :
#
# 40
