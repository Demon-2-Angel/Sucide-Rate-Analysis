# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\Semester 4\Data Analysis\Research Dataset\GapMinder Codebook.csv")

# %%
df.head(15)
# Out:
#                 country incomeperperson alcconsumption armedforcesrate  \
# 0           Afghanistan                           0.03       0.5696534
# 1               Albania     1914.996551           7.29       1.0247361
# 2               Algeria     2231.993335           0.69        2.306817
# 3               Andorra      21943.3399          10.17
# 4                Angola     1381.004268           5.57       1.4613288
# 5   Antigua and Barbuda     11894.46407           8.17
# 6             Argentina     10749.41924           9.35        0.560987
# 7               Armenia     1326.741757          13.66       2.6184384
# 8                 Aruba
# 9             Australia     25249.98606          10.21       0.4862799
# 10              Austria     26692.98411           12.4       0.8155798
# 11           Azerbaijan     2344.896916          13.34       1.9767462
# 12              Bahamas     19630.54055           8.65       0.5452863
# ...

# %%
print("Total Columns : ",len(df.columns))
print("Total Row : ",len(df))
# Out:
# Total Columns :  16
# Total Row :  213

# %%
df.dtypes
# Out:
# country                 object
# incomeperperson         object
# alcconsumption          object
# armedforcesrate         object
# breastcancerper100th    object
# co2emissions            object
# femaleemployrate        object
# hivrate                 object
# internetuserate         object
# lifeexpectancy          object
# oilperperson            object
# polityscore             object
# relectricperperson      object
# suicideper100th         object
# employrate              object
# urbanrate               object
# dtype: object

# %%
df["incomeperperson"][0]
# Out:
# ' '

# %%
df["armedforcesrate"][3]
# Out:
# ' '

# %%
df["breastcancerper100th"][3]
# Out:
# ' '

# %% [markdown]
# This means all the cells given in the excel(.csv file) as blank are type of String.

# %%
df_opp = df[df["oilperperson"]== " "]

print("Empty cells in oilperperson column is :",len(df_opp))
print("Usuable cells are only: ", len(df["oilperperson"])-len(df_opp))
# Out:
# Empty cells in oilperperson column is : 150
# Usuable cells are only:  63

# %% [markdown]
# This is not a good column because out of 213 rows, 150 rows are empty.

# %%
df_repp = df[df["relectricperperson"]== " "]

print("Empty cells in relectricperperson column is :",len(df_repp))
print("Usuable cells are only: ", len(df["relectricperperson"])-len(df_repp))
# Out:
# Empty cells in relectricperperson column is : 77
# Usuable cells are only:  136

# %% [markdown]
# This is a good column to consider, lets change all the empty cells to NAN in these two columns

# %%
'''df = df[df["oilperperson"] == " "].replace(" ", np.nan)
df = df[df["relectricperperson"] == " "].replace(" ", np.nan)'''
# Out:
# 'df = df[df["oilperperson"] == " "].replace(" ", np.nan)\ndf = df[df["relectricperperson"] == " "].replace(" ", np.nan)'

# %%
df.drop(df[df["oilperperson"] == " "].index, inplace = True)
df.drop(df[df["relectricperperson"] == " "].index, inplace = True)

# %%
df
# Out:
#                   country incomeperperson alcconsumption armedforcesrate  \
# 2                 Algeria     2231.993335           0.69        2.306817
# 6               Argentina     10749.41924           9.35        0.560987
# 9               Australia     25249.98606          10.21       0.4862799
# 10                Austria     26692.98411           12.4       0.8155798
# 11             Azerbaijan     2344.896916          13.34       1.9767462
# ..                    ...             ...            ...             ...
# 201  United Arab Emirates     21087.39412           0.52       1.8124763
# 202        United Kingdom     28033.48928          13.24       0.5080181
# 203         United States     37491.17952            9.7       0.9723782
# 205            Uzbekistan     952.8272608           3.61       0.7096295
# 207             Venezuela     5528.363114            7.6       0.9040245
#
#     breastcancerper100th co2emissions femaleemployrate hivrate  \
# ...

# %% [markdown]
# We are going to find data about only 63 countries

# %%
df["oilpersperson"] = df["oilperperson"].astype(float)
df["relectricperperson"] = df["relectricperperson"].astype(float)
df.dtypes
# Out:
# country                  object
# incomeperperson          object
# alcconsumption           object
# armedforcesrate          object
# breastcancerper100th     object
# co2emissions             object
# femaleemployrate         object
# hivrate                  object
# internetuserate          object
# lifeexpectancy           object
# oilperperson             object
# polityscore              object
# relectricperperson      float64
# suicideper100th          object
# employrate               object
# urbanrate                object
# oilpersperson           float64
# dtype: object

# %%
oppcount = df["oilperperson"].value_counts(sort = False).to_frame()
oppcount
# Out:
#              oilperperson
# 0.420094525             1
# 0.635943801             1
# 1.913026109             1
# 1.548790966             1
# 0.35917261              1
# ...                   ...
# 4.299964455             1
# 1.188028094             1
# 2.738543683             1
# 0.182184525             1
# 1.214636773             1
#
# [63 rows x 1 columns]

# %%
relectriccount = df["relectricperperson"].value_counts(sort = False).to_frame()
relectriccount
# Out:
#               relectricperperson
# 590.509814                     1
# 768.428300                     1
# 2825.391095                    1
# 2068.123309                    1
# 921.562111                     1
# ...                          ...
# 11154.755030                   1
# 1933.945615                    1
# 4542.848695                    1
# 261.433953                     1
# 969.004339                     1
#
# [63 rows x 1 columns]

# %% [markdown]
# This informs us that all the data in column of oilperperson and relectricperperson is Unique.

# %% [markdown]
# ## Research Question : Is there any correlation between Oil-per-person and r-electric-per-person?
